# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# ## Importing Dataset

# %%
sales= pd.read_csv("advertising.csv")
sales.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
sales.shape
# Out:
# (200, 4)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
plt.hist(sales['TV'],color='g',bins=25)
plt.show()

# %%
plt.hist(sales['Radio'],color='purple',bins=25)
plt.show()

# %%
plt.hist(sales['Newspaper'],color='r',bins=25)
plt.show()

# %%
plt.hist(sales['Sales'],color='brown',bins=25)
plt.show()

# %%
sales.boxplot()
plt.show()

# %%
sales.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
sales.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
sns.jointplot(sales['TV'],color='g')
plt.show()

# %%
sns.jointplot(sales['Radio'],color='orange')
plt.show()

# %%
sns.jointplot(sales['Newspaper'],color='brown')
plt.show()

# %%
sns.jointplot(sales['Sales'],color='yellow')
plt.show()

# %%
sns.pairplot(sales,x_vars=['TV','Newspaper','Radio'],y_vars='Sales',height=3,aspect=1.5,kind='reg')
plt.show()

# %%
sns.heatmap(sales.corr(),annot=True)
plt.show()

# %% [markdown]
# ## Data Preprocessing

# %%
x = sales.iloc[:, :-1].values
y = sales.iloc[:, -1].values

# %%
x[0:5]
# Out:
# array([[230.1,  37.8,  69.2],
#        [ 44.5,  39.3,  45.1],
#        [ 17.2,  45.9,  69.3],
#        [151.5,  41.3,  58.5],
#        [180.8,  10.8,  58.4]])

# %% [markdown]
# ## Model Training

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size= 0.3,random_state=10)

# %%
scoring= 'accuracy'

# %%
from sklearn.linear_model import LinearRegression

# %%
lr= LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Model Prediction

# %%
y_pre=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pre)
# Out:
# 0.9032402609859365
